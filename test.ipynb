# %%
from chatonyourdata import *

# %%
chatter = ChatOnYourData(index="good-fish", role="test-role")
question = "tell me about fish"
chat_history = []

content  = chatter.make_request2(question, chat_history, 1)
# Out:
# azure_openai_key: aebd0ecddf134907b076f234cd9cb77e
# azure_openai_endpoint: https://xmm-openai-eastus.openai.azure.com/
# azure_openai_deployment_name: gpt-4
# azure_openai_embedding_model_name: text-embedding-ada-002
# azure_openai_version: 2023-07-01-preview
# cog_search_service_name: search-memasanz-ai
# cog_search_service_endpoint: https://search-memasanz-ai.search.windows.net
# cog_search_service_key: h5g4poJSnPJN8eL5U5HFzgQ085kaBtnz1ifef6PAbDAzSeBVvyMu
# cog_search_index_name: vector-fish
# cog_search_semantic_config: vector-fish-semantic-configuration
# azure_openai_roleInfo: test-role
# index: good-fish
# url: https://xmm-openai-eastus.openai.azure.com//openai/deployments/gpt-4/chat/completions?api-version=2023-07-01-preview
# FishingGuide.pdf
#
#
# FishingGuide.pdf
#
#
# FishingGuide.pdf
#
#
# FishingGuide.pdf
#
#
# FishingGuide.pdf
#
#
# None
#
#
# None
#
#
# None
#
#
# None
#
#
# None
#
#
# remain in the nest.
#
# Channel Catfish
# Range:
# Statewide.
# Preferred
# ...

# %%
content
# Out:
# "The documents provided contain detailed information about various aspects of fishing, including types of fish, their habitats, food habits, and spawning behaviors. Here's a summary based on the information from the documents:\n\n1. **Channel Catfish**:\n   - **Habitat**: Inhabit a variety of habitats including creeks, rivers, reservoirs, and ponds over a range of substrates.\n   - **Food Habits**: Diet includes fish, crayfish, mollusks, immature mayflies and caddisflies, and aquatic vegetation.\n   - **Spawning**: Occurs from May to July at water temperatures of approximately 70-80°F. Eggs are deposited in nests constructed by the male in secluded areas[doc1](remain in the nest.\n\nChannel Catfish\nRange: \nStatewide.\nPreferred \nHabitat: \nThe channel \ncatfish \ninhabits \na variety of habitat types \nincluding small to large creeks, rivers, reservoirs and \nponds over a range of substrates.  \nFood Habits: Fish, crayfish, mollusks, immature mayflies and caddisflies, as well as \
# ...

# %%
content
# Out:
# "The documents provided offer a comprehensive guide on various aspects of fish, including their habitat preferences, spawning behaviors, and food habits across different species of catfish, bass, sunfish, and more. Here's a summary based on the information from the documents:\n\n1. **Catfish Species**:\n   - **Channel Catfish**: Inhabit a variety of habitats including creeks, rivers, reservoirs, and ponds. They feed on fish, crayfish, mollusks, and aquatic vegetation. Spawning occurs from May to July at water temperatures of approximately 70-80°F, with nests guarded by males [doc1].\n   - **Flathead Catfish**: Found in river drainages and prefer deep holes in sluggish waters. Their diet is primarily fish. Spawning in South Carolina happens from mid-May to mid-July around hollow logs and undercut banks [doc1].\n   - **Blue Catfish**: Native to the Mississippi River basin and found in rivers and large creeks with moderate to swift current. They feed on a variety of organisms including 
# ...
